# %%
# %%html
# <link href='https://fonts.googleapis.com/css?family=Roboto' rel='stylesheet'>
# <style>
# body {
#     font-family: 'Roboto', 'Helvetica', sans-serif;
#     font-size: 16px;
# }
# </style>
# Out:
# <link href='https://fonts.googleapis.com/css?family=Roboto' rel='stylesheet'>
# <style>
# body {
#     font-family: 'Roboto', 'Helvetica', sans-serif;
#     font-size: 16px;
# }
# </style>

# %% [markdown]
# <div style="background-color: #2b3237; padding-top: 20px;
#   padding-right: 30px;
#   padding-bottom: 10px;
#   padding-left: 30px; width: 100%; display: flex">
#
# <div style="background-color: ##2b3237; padding-top: 20px;
#   padding-right: 30px;
#   padding-bottom: 10px;
#   padding-left: 30px; width: 90%">
#
# <p><font color=#ffffff size=6> Regional Voting Preferences in the 2016 Philippine Elections </font></p>
#
# </div>
# </div>
#
# <div style="background-color: #425564; padding-top: 20px;
#   padding-right: 15px;
#   padding-bottom: 20px;
#   padding-left: 15px">
# <font color=#ffffff> George Allan Esleta (gesleta@aim.edu) </font>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import geopandas as gpd
from IPython.display import HTML

# %%
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# <div><span style="background-color: #425564; padding-top: 100px; padding-right: 20px; padding-bottom: 50px; padding-left: 20px; color: #ffffff; font-size: 20px; font-weight: bold">TASK </span></div>

# %% [markdown]
# 1.	Create a denormalized table replacing `precinct_code` in the `results_*.csv` files with the columns: region, province, municipality, and barangay.
# 2.	Create an interesting data visualization using this dataset.

# %% [markdown]
# <div><span style="background-color: #425564; padding-top: 100px; padding-right: 20px; padding-bottom: 50px; padding-left: 20px; color: #ffffff; font-size: 20px; font-weight: bold">DATA </span></div>

# %% [markdown]
# There are three (3) data sources, namely:

# %% [markdown]
# - `ref_table_precinct_locations_PSGC.csv` – lookup table for precincts
# - `results_president.csv` – precinct-level election results for the 2016 presidential race
# - `results_vice-president.csv` – precinct-level election results for the 2016 vice presidential race

# %% [markdown]
# ## 1. Precinct Data

# %% [markdown]
# Workflow:
# 1. Load precinct data
# 2. Check data columns
# 3. Check for missing/ null values

# %% [markdown]
# ### a. Load precint data

# %%
df_precinct = pd.read_csv('Datasets/ref_table_precinct_locations_PSGC.csv')

# %%
df_precinct.head()

# %% [markdown]
# ### b. Check data columns

# %%
df_precinct.info()

# %% [markdown]
# There are **90,642** precinct entries in the data. The `precinct` lookup table has the following columns:

# %%
df_precinct.shape

# %% [markdown]
# | Column | Data type | Description |
# |---|---|---|
# | `precinct_code`  | int | Unique identification number of the precinct |
# |`region           ` | categorical | Administrative region where the precinct is located |
# |`province         ` |object | Province where the precinct is located |
# |`municipality     ` |object | Municipality/City where the precinct is located |
# |`barangay         ` |object | Barangay where the precinct is located |
# |`registered_voters` |int64  | Number of registered voters in the precinct |
# |`ballots_cast     ` |int64  | Number of votes cast in the precinct |
# |`PSGC_CM          ` |object | Philippine Standard Geographic Code (PSGC) for the city/municipality |
# |`is_city          ` |boolean| True if the LGU is a city |
# |`income_class     ` |object | Income class of the city/municipality |
# |`population       ` |float64| Population of the city/municipality |
# |`land_area        ` |float64| Land area of the city/municipality |
# |`province_CM      ` |object | Name of the province in the PSGC database |
# |`municipality_CM  ` |object | Name of the municipality/city in the PSGC database |

# %% [markdown]
# ### c. Check for null values

# %% [markdown]
# The precinct data has no missing/ null values for the `precinct_code`, `region`, `province`, `municipality`, and `barangay` columns.

# %%
df_precinct.isnull().sum()

# %% [markdown]
# ### d. Checking for uniqueness and duplicates

# %% [markdown]
# The `precinct_code` column has no duplicate values.

# %%
df_precinct.nunique(axis=0, dropna=True)

# %% [markdown]
# ### e. Check unique values of Region

# %% [markdown]
# There are **nineteen (19)** unique regions in the precinct lookup data:

# %%
print(f"There are {df_precinct['region'].nunique()} unique regions.")

# %%
print(sorted(df_precinct['region'].unique()))

# %% [markdown]
# Note that ***Overseas Absentee Voters (OAV)*** are considered as a separate administrative region. Also, **Negros Island Region (NIR)**, which was dissolved in 2017, is still included in the database.

# %% [markdown]
# ### f. Check unique values of Province

# %% [markdown]
# There are two (2) province-related columns: `province` and `province_CM`. Checking if there are discrepancies between the two columns:

# %%
df_precinct[df_precinct['province_CM'] != df_precinct['province']].shape

# %% [markdown]
# The two columns have identical values for all records and therefore can be used interchangeably. For simplicity, the `province_CM` column will be used, as this is the official name of the province in the PSA records.

# %% [markdown]
# There are **ninety (90)** unique `province` values:

# %%
print(sorted(df_precinct['province_CM'].unique()))

# %% [markdown]
# ### f. Check unique values of Municipality

# %% [markdown]
# There are two (2) municipality-related columns: `municipality` and `municipality_CM`. Checking if there are discrepancies between the two columns:

# %%
df_precinct[df_precinct['municipality_CM'] != df_precinct['municipality']].shape

# %% [markdown]
# For the National Capital Region, the `municipality` column contains district names instead of the city name.

# %%
df_precinct[df_precinct['municipality_CM'] != df_precinct['municipality']].head()

# %% [markdown]
# The `municipality_CM` column will be used moving forward.

# %% [markdown]
# ### g. Drop `province` and `municipality` columns

# %%
df_precinct.drop(['Unnamed: 0', 'province', 'municipality'], axis=1, inplace=True)

# %% [markdown]
# ### i. rename columns

# %%
df_precinct.rename(columns={'province_CM': 'province', 'municipality_CM': 'municipality'}, inplace=True)

# %%
df_precinct.columns

# %% [markdown]
# ### Create mapping of region with provinces

# %% [markdown]
# We check the accuracy of the `region` and `province` fields in the precinct database by creating a region-province mapping from the data. The data was grouped by region, and the unique province values for each region was obtained. The resulting mapping is saved in a dictionary `region_map`.

# %%
region_map = dict(df_precinct[['region', 'province']].groupby('region')['province'].unique().apply(lambda x: sorted(list(x))))

# %%
with open('Datasets/regions_mapping.pkl', 'wb') as f:
    pickle.dump(region_map, f)

# %%
with open('Datasets/regions_mapping.pkl', 'rb') as f:
    region_map = pickle.load(f)

# %%
regions = list(region_map.keys())

# %%
regions

# %%
for region in regions:
    print(f'{region}')
    for province in region_map[region]:
        print(f'\t{province}')

# %%
cols = ['precinct_code', 'region', 'province', 'municipality', 'barangay']

# %% [markdown]
# ## 2 President Data

# %%
df_president = pd.read_csv('Datasets/results_president.csv')

# %%
df_president.head()

# %%
df_president.shape

# %%
df_president.columns

# %%
print(df_president.info())

# %%
df_president.isnull().sum()

# %%
df_president.nunique()

# %%
print(sorted(df_president['candidate_name'].unique()))

# %%
df_pres_merged = pd.merge(df_president, df_precinct[cols], on='precinct_code', how='left')

# %%
df_pres_merged.shape

# %%
df_pres_merged.isnull().sum()

# %%
df_pres_merged.drop(['precinct_code'], axis=1, inplace=True)

# %%
df_pres_merged.head()

# %%
with open('Datasets/president_merged.pkl', 'wb') as f:
    pickle.dump(df_pres_merged, f)

# %% [markdown]
# ## 2 Vice-President Data

# %%
df_vp = pd.read_csv('Datasets/results_vice-president.csv')

# %%
df_vp.head()

# %%
df_vp.shape

# %%
print(df_vp.info())

# %%
df_vp.isnull().sum()

# %%
df_vp.nunique()

# %%
print(sorted(df_vp['candidate_name'].unique()))

# %%
df_vp_merged = pd.merge(df_vp, df_precinct[cols], on='precinct_code', how='left')

# %%
df_vp_merged.head()

# %%
df_vp_merged.isnull().sum()

# %%
df_vp_merged.drop(['precinct_code'], axis=1, inplace=True)

# %%
df_vp_merged

# %%
with open('Datasets/vice-president_merged.pkl', 'wb') as f:
    pickle.dump(df_vp_merged, f)

# %% [markdown]
# ## Questions
#
# 1. Which regions/provinces do block voting; i,e, vote for the President and Vice President candidate from the same party?
# 2. Bailwicks per candidate

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# The denormalized presidential and vice-presidential election results are explored below.

# %%
with open('Datasets/president_merged.pkl', 'rb') as f:
    df_pres = pickle.load(f)

# %%
with open('Datasets/vice-president_merged.pkl', 'rb') as f:
    df_vp = pickle.load(f)

# %% [markdown]
# ### 1. Total votes

# %%
df_pres['votes'].sum()
# Out:
# 41278124

# %%
df_vp['votes'].sum()
# Out:
# 39832254

# %% [markdown]
# ### 2. Total votes per candidate

# %%
fig, ax = plt.subplots(dpi=150)
df_pres.groupby('candidate_name')['votes'].agg(sum).sort_values(ascending=True).plot(kind='barh', color='#43a1e5', ax=ax, width=0.7)
ax.set_ylabel('Candidate')
ax.set_xlabel('Number of votes');

# %%
fig, ax = plt.subplots(dpi=150)
df_vp.groupby('candidate_name')['votes'].agg(sum).sort_values(ascending=True).plot(kind='barh', color='#43a1e5', ax=ax, width=0.7)
ax.set_ylabel('Candidate')
ax.set_xlabel('Number of votes');

# %% [markdown]
# ## Total Votes per Region

# %%
fig, ax = plt.subplots(dpi=150)
df_pres.groupby('region')['votes'].agg(sum).sort_values(ascending=True).plot(kind='barh', color='#43a1e5', ax=ax, width=0.7)
ax.set_ylabel('Region')
ax.set_xlabel('Number of president votes');

# %%
fig, ax = plt.subplots(dpi=150)
df_vp.groupby('region')['votes'].agg(sum).sort_values(ascending=True).plot(kind='barh', color='#43a1e5', ax=ax, width=0.7)
ax.set_ylabel('Region')
ax.set_xlabel('Number of vice president votes');

# %% [markdown]
# ## Total Votes per Province

# %%
fig, ax = plt.subplots(dpi=150, figsize=(8,4))
df_pres.groupby('province')['votes'].agg(sum).sort_values(ascending=True)[-15:].plot(kind='barh', color='#43a1e5', ax=ax, width=0.7)
ax.set_ylabel('Province')
ax.set_xlabel('Number of president votes');

# %%
fig, ax = plt.subplots(dpi=150, figsize=(8,4))
df_vp.groupby('province')['votes'].agg(sum).sort_values(ascending=True)[-15:].plot(kind='barh', color='#43a1e5', ax=ax, width=0.7)
ax.set_ylabel('Province')
ax.set_xlabel('Number of vice president votes');

# %% [markdown]
# ## Votes Heatmap

# %% [markdown]
# ### President

# %%
df_pres_pivot = pd.pivot_table(df_pres, index='candidate_name', columns='region', values='votes', aggfunc=sum)

# %%
df_pres_pivot_norm = df_pres_pivot.div(df_pres_pivot.sum(axis=0), axis=1)

# %%
fig, ax = plt.subplots(dpi=150, figsize=(10,3))
sns.heatmap(df_pres_pivot, ax=ax, cmap='hot', square=True)
ax.set_xlabel('Region')
ax.set_ylabel('Candidate')
ax.set_title('Presidential votes heatmap')
plt.xticks(rotation=60);

# %%
fig, ax = plt.subplots(dpi=150, figsize=(10,3))
sns.heatmap(df_pres_pivot_norm, ax=ax, cmap='hot', square=True)
ax.set_xlabel('Region')
ax.set_ylabel('Candidate')
ax.set_title('Presidential votes heatmap (normalized per region)')
plt.xticks(rotation=60);

# %% [markdown]
# ## Vice President

# %%
df_vp_pivot = pd.pivot_table(df_vp, index='candidate_name', columns='region', values='votes', aggfunc=sum)

# %%
df_vp_pivot_norm = df_vp_pivot.div(df_vp_pivot.sum(axis=0), axis=1)

# %%
fig, ax = plt.subplots(dpi=150, figsize=(10,3))
sns.heatmap(df_vp_pivot, ax=ax, cmap='hot', square=True)
ax.set_xlabel('Region')
ax.set_ylabel('Candidate')
ax.set_title('Vice-Presidential votes heatmap')
plt.xticks(rotation=60);

# %%
fig, ax = plt.subplots(dpi=150, figsize=(10,3))
sns.heatmap(df_vp_pivot_norm, ax=ax, cmap='hot', square=True)
ax.set_xlabel('Region')
ax.set_ylabel('Candidate')
ax.set_title('Vice-Presidential votes heatmap (normalized per region)')
plt.xticks(rotation=60);

# %% [markdown]
# Marcos obtained landslide wins in the northern Luzon regions, specifically Region 1 (Ilocos), Region 2 (Cagayan Valley), and CAR. However, this is not enough to surpass the combined votes obtained by Robredo in the southern regions, specifically in Region 5, Region 6, and NIR.

# %% [markdown]
# ## Ranking of candidates per region

# %% [markdown]
# ### Presidential Race

# %%
df_pres_ranking = df_pres.groupby(['region','candidate_name']).agg({'votes': sum})

# %%
df_pres_ranking['rank'] = df_pres_ranking.groupby('region')['votes'].rank(method='dense', ascending=False)

# %%
df_pres_ranking.reset_index(inplace=True)

# %%
df_pres_ranking_pivot = df_pres_ranking.pivot(index='candidate_name', columns='region')['rank']

# %%
fig, ax = plt.subplots(dpi=150, figsize=(10,3))
sns.heatmap(df_pres_ranking_pivot, ax=ax, cmap='hot_r', square=True)
ax.set_xlabel('Region')
ax.set_ylabel('Candidate')
ax.set_title('Presidential ranking heatmap')
plt.xticks(rotation=60);

# %% [markdown]
# ### Vice-Presidential Race

# %%
df_vp_ranking = df_vp.groupby(['region','candidate_name']).agg({'votes': sum})

# %%
df_vp_ranking['rank'] = df_vp_ranking.groupby('region')['votes'].rank(method='dense', ascending=False)

# %%
df_vp_ranking.reset_index(inplace=True)

# %%
df_vp_ranking_pivot = df_vp_ranking.pivot(index='candidate_name', columns='region')['rank']

# %%
fig, ax = plt.subplots(dpi=150, figsize=(10,3))
sns.heatmap(df_vp_ranking_pivot, ax=ax, cmap='hot_r', square=True)
ax.set_xlabel('Region')
ax.set_ylabel('Candidate')
ax.set_title('Vice-Presidential ranking heatmap')
plt.xticks(rotation=60);

# %% [markdown]
# ## Geopandas

# %%
fig, ax = plt.subplots(1, figsize=(10, 15), frameon=True)

ph0 = gpd.GeoDataFrame.from_file("Datasets/ph_regions.shp")
ph0.plot(ax=ax, cmap='Greens', edgecolor='#555555', k=18)
ax.set_title('Regions of the Philippines')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

for ind, row in ph0.iterrows():
    ax.text(row["geometry"].centroid.x, row["geometry"].centroid.y,
            row["region"])

# %%
ph0['PROVINCE'] = ph0['PROVINCE'].apply(lambda x: x.upper())

# %%
region_map
# Out:
# {'ARMM': ['BASILAN', 'LANAO DEL SUR', 'MAGUINDANAO', 'SULU', 'TAWI-TAWI'],
#  'CAR': ['ABRA',
#   'APAYAO',
#   'BENGUET',
#   'IFUGAO',
#   'KALINGA',
#   'MOUNTAIN PROVINCE'],
#  'NCR': ['NATIONAL CAPITAL REGION - FOURTH DISTRICT',
#   'NATIONAL CAPITAL REGION - MANILA',
#   'NATIONAL CAPITAL REGION - SECOND DISTRICT',
#   'NATIONAL CAPITAL REGION - THIRD DISTRICT',
#   'TAGUIG - PATEROS'],
#  'NIR': ['NEGROS OCCIDENTAL', 'NEGROS ORIENTAL'],
#  'OAV': ['ASIA',
#   'EUROPE',
#   'MIDDLE EAST AND AFRICAS',
#   'NORTH AND LATIN AMERICA'],
#  'REGION I': ['ILOCOS NORTE', 'ILOCOS SUR', 'LA UNION', 'PANGASINAN'],
#  'REGION II': ['BATANES', 'CAGAYAN', 'ISABELA', 'NUEVA VIZCAYA', 'QUIRINO'],
#  'REGION III': ['AURORA',
#   'BATAAN',
#   'BULACAN',
#   'NUEVA ECIJA',
#   'PAMPANGA',
#   'TARLAC',
#   'ZAMBALES'],
#  'REGION IV-A': ['BATANGAS', 'CAVITE', 'LAGUNA', 'QUEZON', 'RIZAL'],
#  'REGION IV-B': ['MARINDUQUE',
#   'OCCIDENTAL MINDORO',
#   'ORIENTAL MINDORO',
#   'PALAWAN',
#   'ROMBLON'],
#  'REGION IX': ['ZAMBOANGA DEL NORTE',
#   'ZAMBOANGA DEL SUR',
#   'ZAMBOANGA SIBUGAY'],
#  'REGION V': ['ALBAY',
#   'CAMARINES NORTE',
#   'CAMARINES SUR',
#   'CATANDUANES',
#   'MASBATE',
#   'SORSOGON'],
#  'REGION VI': ['AKLAN', 'ANTIQUE', 'CAPIZ', 'GUIMARAS', 'ILOILO'],
#  'REGION VII': ['BOHOL', 'CEBU', 'SIQUIJOR'],
#  'REGION VIII': ['BILIRAN',
#   'EASTERN SAMAR',
#   'LEYTE',
#   'NORTHERN SAMAR',
#   'SAMAR (WESTERN SAMAR)',
#   'SOUTHERN LEYTE'],
#  'REGION X': ['BUKIDNON',
#   'CAMIGUIN',
#   'LANAO DEL NORTE',
#   'MISAMIS OCCIDENTAL',
#   'MISAMIS ORIENTAL'],
#  'REGION XI': ['COMPOSTELA VALLEY',
#   'DAVAO (DAVAO DEL NORTE)',
#   'DAVAO DEL SUR',
#   'DAVAO OCCIDENTAL',
#   'DAVAO ORIENTAL'],
#  'REGION XII': ['COTABATO (NORTH COT.)',
#   'SARANGANI',
#   'SOUTH COTABATO',
#   'SULTAN KUDARAT'],
#  'REGION XIII': ['AGUSAN DEL NORTE',
#   'AGUSAN DEL SUR',
#   'DINAGAT ISLANDS',
#   'SURIGAO DEL NORTE',
#   'SURIGAO DEL SUR']}

# %%
set(df_pres['province'].unique()).difference(set(ph0['PROVINCE'].unique()))
# Out:
# {'ASIA',
#  'COTABATO (NORTH COT.)',
#  'DAVAO (DAVAO DEL NORTE)',
#  'DAVAO OCCIDENTAL',
#  'EUROPE',
#  'MIDDLE EAST AND AFRICAS',
#  'NATIONAL CAPITAL REGION - FOURTH DISTRICT',
#  'NATIONAL CAPITAL REGION - MANILA',
#  'NATIONAL CAPITAL REGION - SECOND DISTRICT',
#  'NATIONAL CAPITAL REGION - THIRD DISTRICT',
#  'NORTH AND LATIN AMERICA',
#  'SAMAR (WESTERN SAMAR)',
#  'TAGUIG - PATEROS',
#  nan}

# %%
ph0
# Out:
#     ID_0  ISO       NAME_0  ID_1               NAME_1 NL_NAME_1  \
# 0    177  PHL  Philippines     1                 Abra      None
# 1    177  PHL  Philippines     2     Agusan del Norte      None
# 2    177  PHL  Philippines     3       Agusan del Sur      None
# 3    177  PHL  Philippines     4                Aklan      None
# 4    177  PHL  Philippines     5                Albay      None
# 5    177  PHL  Philippines     6              Antique      None
# 6    177  PHL  Philippines     7               Apayao      None
# 7    177  PHL  Philippines     8               Aurora      None
# 8    177  PHL  Philippines     9              Basilan      None
# 9    177  PHL  Philippines    10               Bataan      None
# 10   177  PHL  Philippines    11              Batanes      None
# 11   177  PHL  Philippines    12             Batangas      None
# 12   177  PHL  Philippines    13              Benguet      None
# 13   177  PHL  Philippines    14              Biliran      None
# 14   177  PHL  Philippines    15                Bohol      None
# 15   177  PHL  Philippines    16             Bukidnon      None
# 16   177  PHL  Philippines    17              Bulacan      None
# 17   177  PHL  Philippines    18              Cagayan      None
# 18   177  PHL  Philippines    19      Camarines Norte      None
# 19   177  PHL  Philippines    20        Camarines Sur      None
# 20   177  PHL  Philippines    21             Camiguin      None
# 21   177  PHL  Philippines    22                Capiz      None
# 22   177  PHL  Philippines    23          Catanduanes      None
# 23   177  PHL  Philippines    24               Cavite      None
# 24   177  PHL  Philippines    25                 Cebu      None
# 25   177  PHL  Philippines    26    Compostela Valley      None
# 26   177  PHL  Philippines    27      Davao del Norte      None
# 27   177  PHL  Philippines    28        Davao del Sur      None
# 28   177  PHL  Philippines    29       Davao Oriental      None
# 29   177  PHL  Philippines    30      Dinagat Islands      None
# ..   ...  ...          ...   ...                  ...       ...
# 52   177  PHL  Philippines    53       North Cotabato      None
# 53   177  PHL  Philippines    54       Northern Samar      None
# 54   177  PHL  Philippines    55          Nueva Ecija      None
# 55   177  PHL  Philippines    56        Nueva Vizcaya      None
# 56   177  PHL  Philippines    57   Occidental Mindoro      None
# 57   177  PHL  Philippines    58     Oriental Mindoro      None
# 58   177  PHL  Philippines    59              Palawan      None
# 59   177  PHL  Philippines    60             Pampanga      None
# 60   177  PHL  Philippines    61           Pangasinan      None
# 61   177  PHL  Philippines    62               Quezon      None
# 62   177  PHL  Philippines    63              Quirino      None
# 63   177  PHL  Philippines    64                Rizal      None
# 64   177  PHL  Philippines    65              Romblon      None
# 65   177  PHL  Philippines    66                Samar      None
# 66   177  PHL  Philippines    67            Sarangani      None
# 67   177  PHL  Philippines    68    Shariff Kabunsuan      None
# 68   177  PHL  Philippines    69             Siquijor      None
# 69   177  PHL  Philippines    70             Sorsogon      None
# 70   177  PHL  Philippines    71       South Cotabato      None
# 71   177  PHL  Philippines    72       Southern Leyte      None
# 72   177  PHL  Philippines    73       Sultan Kudarat      None
# 73   177  PHL  Philippines    74                 Sulu      None
# 74   177  PHL  Philippines    75    Surigao del Norte      None
# 75   177  PHL  Philippines    76      Surigao del Sur      None
# 76   177  PHL  Philippines    77               Tarlac      None
# 77   177  PHL  Philippines    78            Tawi-Tawi      None
# 78   177  PHL  Philippines    79             Zambales      None
# 79   177  PHL  Philippines    80  Zamboanga del Norte      None
# 80   177  PHL  Philippines    81    Zamboanga del Sur      None
# 81   177  PHL  Philippines    82    Zamboanga Sibugay      None
#
#         VARNAME_1               TYPE_1 ENGTYPE_1             PROVINCE  \
# 0            None  Lalawigan|Probinsya  Province                 ABRA
# 1            None  Lalawigan|Probinsya  Province     AGUSAN DEL NORTE
# 2            None  Lalawigan|Probinsya  Province       AGUSAN DEL SUR
# 3            None  Lalawigan|Probinsya  Province                AKLAN
# 4            None  Lalawigan|Probinsya  Province                ALBAY
# 5            None  Lalawigan|Probinsya  Province              ANTIQUE
# 6            None  Lalawigan|Probinsya  Province               APAYAO
# 7            None  Lalawigan|Probinsya  Province               AURORA
# 8            None  Lalawigan|Probinsya  Province              BASILAN
# 9            None  Lalawigan|Probinsya  Province               BATAAN
# 10           None  Lalawigan|Probinsya  Province              BATANES
# 11           None  Lalawigan|Probinsya  Province             BATANGAS
# 12           None  Lalawigan|Probinsya  Province              BENGUET
# 13           None  Lalawigan|Probinsya  Province              BILIRAN
# 14           None  Lalawigan|Probinsya  Province                BOHOL
# 15           None  Lalawigan|Probinsya  Province             BUKIDNON
# 16           None  Lalawigan|Probinsya  Province              BULACAN
# 17           None  Lalawigan|Probinsya  Province              CAGAYAN
# 18           None  Lalawigan|Probinsya  Province      CAMARINES NORTE
# 19           None  Lalawigan|Probinsya  Province        CAMARINES SUR
# 20           None  Lalawigan|Probinsya  Province             CAMIGUIN
# 21           None  Lalawigan|Probinsya  Province                CAPIZ
# 22           None  Lalawigan|Probinsya  Province          CATANDUANES
# 23           None  Lalawigan|Probinsya  Province               CAVITE
# 24           None  Lalawigan|Probinsya  Province                 CEBU
# 25           None  Lalawigan|Probinsya  Province    COMPOSTELA VALLEY
# 26          Davao  Lalawigan|Probinsya  Province      DAVAO DEL NORTE
# 27           None  Lalawigan|Probinsya  Province        DAVAO DEL SUR
# 28           None  Lalawigan|Probinsya  Province       DAVAO ORIENTAL
# 29           None  Lalawigan|Probinsya  Province      DINAGAT ISLANDS
# ..            ...                  ...       ...                  ...
# 52           None  Lalawigan|Probinsya  Province       NORTH COTABATO
# 53           None  Lalawigan|Probinsya  Province       NORTHERN SAMAR
# 54           None  Lalawigan|Probinsya  Province          NUEVA ECIJA
# 55           None  Lalawigan|Probinsya  Province        NUEVA VIZCAYA
# 56           None  Lalawigan|Probinsya  Province   OCCIDENTAL MINDORO
# 57           None  Lalawigan|Probinsya  Province     ORIENTAL MINDORO
# 58        Paragua  Lalawigan|Probinsya  Province              PALAWAN
# 59           None  Lalawigan|Probinsya  Province             PAMPANGA
# 60           None  Lalawigan|Probinsya  Province           PANGASINAN
# 61           None  Lalawigan|Probinsya  Province               QUEZON
# 62           None  Lalawigan|Probinsya  Province              QUIRINO
# 63           None  Lalawigan|Probinsya  Province                RIZAL
# 64           None  Lalawigan|Probinsya  Province              ROMBLON
# 65  Western Samar  Lalawigan|Probinsya  Province                SAMAR
# 66           None  Lalawigan|Probinsya  Province            SARANGANI
# 67           None  Lalawigan|Probinsya  Province    SHARIFF KABUNSUAN
# 68           None  Lalawigan|Probinsya  Province             SIQUIJOR
# 69           None  Lalawigan|Probinsya  Province             SORSOGON
# 70           None  Lalawigan|Probinsya  Province       SOUTH COTABATO
# 71           None  Lalawigan|Probinsya  Province       SOUTHERN LEYTE
# 72           None  Lalawigan|Probinsya  Province       SULTAN KUDARAT
# 73           None  Lalawigan|Probinsya  Province                 SULU
# 74           None  Lalawigan|Probinsya  Province    SURIGAO DEL NORTE
# 75           None  Lalawigan|Probinsya  Province      SURIGAO DEL SUR
# 76           None  Lalawigan|Probinsya  Province               TARLAC
# 77           None  Lalawigan|Probinsya  Province            TAWI-TAWI
# 78           None  Lalawigan|Probinsya  Province             ZAMBALES
# 79           None  Lalawigan|Probinsya  Province  ZAMBOANGA DEL NORTE
# 80           None  Lalawigan|Probinsya  Province    ZAMBOANGA DEL SUR
# 81           None  Lalawigan|Probinsya  Province    ZAMBOANGA SIBUGAY
#
#                                          REGION  \
# 0        Cordillera Administrative Region (CAR)
# 1                          Caraga (Region XIII)
# 2                          Caraga (Region XIII)
# 3                   Western Visayas (Region VI)
# 4                       Bicol Region (Region V)
# 5                   Western Visayas (Region VI)
# 6        Cordillera Administrative Region (CAR)
# 7                    Central Luzon (Region III)
# 8   Autonomous Region of Muslim Mindanao (ARMM)
# 9                    Central Luzon (Region III)
# 10                   Cagayan Valley (Region II)
# 11                     CALABARZON (Region IV-A)
# 12       Cordillera Administrative Region (CAR)
# 13                Eastern Visayas (Region VIII)
# 14                 Central Visayas (Region VII)
# 15                 Northern Mindanao (Region X)
# 16                   Central Luzon (Region III)
# 17                   Cagayan Valley (Region II)
# 18                      Bicol Region (Region V)
# 19                      Bicol Region (Region V)
# 20                 Northern Mindanao (Region X)
# 21                  Western Visayas (Region VI)
# 22                      Bicol Region (Region V)
# 23                     CALABARZON (Region IV-A)
# 24                 Central Visayas (Region VII)
# 25                     Davao Region (Region XI)
# 26                     Davao Region (Region XI)
# 27                     Davao Region (Region XI)
# 28                     Davao Region (Region XI)
# 29                         Caraga (Region XIII)
# ..                                          ...
# 52                    SOCCSKSARGEN (Region XII)
# 53                Eastern Visayas (Region VIII)
# 54                   Central Luzon (Region III)
# 55                   Cagayan Valley (Region II)
# 56                       MIMAROPA (Region IV-B)
# 57                       MIMAROPA (Region IV-B)
# 58                       MIMAROPA (Region IV-B)
# 59                   Central Luzon (Region III)
# 60                     Ilocos Region (Region I)
# 61                     CALABARZON (Region IV-A)
# 62                   Cagayan Valley (Region II)
# 63                     CALABARZON (Region IV-A)
# 64                       MIMAROPA (Region IV-B)
# 65                Eastern Visayas (Region VIII)
# 66                    SOCCSKSARGEN (Region XII)
# 67  Autonomous Region of Muslim Mindanao (ARMM)
# 68                 Central Visayas (Region VII)
# 69                      Bicol Region (Region V)
# 70                    SOCCSKSARGEN (Region XII)
# 71                Eastern Visayas (Region VIII)
# 72                    SOCCSKSARGEN (Region XII)
# 73  Autonomous Region of Muslim Mindanao (ARMM)
# 74                         Caraga (Region XIII)
# 75                         Caraga (Region XIII)
# 76                   Central Luzon (Region III)
# 77  Autonomous Region of Muslim Mindanao (ARMM)
# 78                   Central Luzon (Region III)
# 79              Zamboanga Peninsula (Region IX)
# 80              Zamboanga Peninsula (Region IX)
# 81              Zamboanga Peninsula (Region IX)
#
#                                              geometry
# 0   POLYGON ((120.96795 17.95706, 120.97803 17.949...
# 1   POLYGON ((125.57724 9.45679, 125.59687 9.45509...
# 2   POLYGON ((125.91087 8.85625, 125.91461 8.85211...
# 3   MULTIPOLYGON (((122.43667 11.59833, 122.43667 ...
# 4   MULTIPOLYGON (((123.28764 13.04923, 123.28686 ...
# 5   MULTIPOLYGON (((121.92085 10.42076, 121.92107 ...
# 6   POLYGON ((121.33075 17.85327, 121.32558 17.845...
# 7   MULTIPOLYGON (((121.57475 15.59574, 121.57412 ...
# 8   MULTIPOLYGON (((121.96861 6.28222, 121.96806 6...
# 9   MULTIPOLYGON (((120.62363 14.36788, 120.62368 ...
# 10  MULTIPOLYGON (((121.81361 20.33472, 121.81361 ...
# 11  MULTIPOLYGON (((121.08528 13.57333, 121.08556 ...
# 12  POLYGON ((120.79335 16.91904, 120.80403 16.907...
# 13  MULTIPOLYGON (((124.26632 11.58278, 124.26692 ...
# 14  MULTIPOLYGON (((123.92167 9.48583, 123.92111 9...
# 15  POLYGON ((124.89146 8.59255, 124.91908 8.58956...
# 16  MULTIPOLYGON (((121.00214 14.73724, 121.00198 ...
# 17  MULTIPOLYGON (((122.32695 18.24817, 122.32809 ...
# 18  MULTIPOLYGON (((123.10680 14.04700, 123.10735 ...
# 19  MULTIPOLYGON (((123.05878 13.49125, 123.05807 ...
# 20  POLYGON ((124.71012 9.25738, 124.71056 9.25694...
# 21  MULTIPOLYGON (((122.88107 11.44462, 122.88052 ...
# 22  MULTIPOLYGON (((124.33555 13.56307, 124.33611 ...
# 23  MULTIPOLYGON (((120.61583 14.26396, 120.61562 ...
# 24  MULTIPOLYGON (((123.38955 9.43467, 123.39031 9...
# 25  MULTIPOLYGON (((125.83264 7.26979, 125.83264 7...
# 26  MULTIPOLYGON (((125.68475 6.96153, 125.68595 6...
# 27  MULTIPOLYGON (((125.39778 5.43583, 125.39778 5...
# 28  MULTIPOLYGON (((126.06885 6.62813, 126.06888 6...
# 29  MULTIPOLYGON (((125.64250 9.92667, 125.64278 9...
# ..                                                ...
# 52  POLYGON ((124.53799 7.68187, 124.54649 7.68032...
# 53  MULTIPOLYGON (((124.09972 12.29028, 124.10028 ...
# 54  POLYGON ((120.98804 16.12756, 121.00216 16.125...
# 55  POLYGON ((121.34143 16.74690, 121.35690 16.730...
# 56  MULTIPOLYGON (((121.02194 12.20611, 121.02222 ...
# 57  MULTIPOLYGON (((121.43574 12.20257, 121.43555 ...
# 58  MULTIPOLYGON (((117.31389 7.51417, 117.31416 7...
# 59  MULTIPOLYGON (((120.61667 14.80000, 120.61584 ...
# 60  MULTIPOLYGON (((119.86505 15.81170, 119.86479 ...
# 61  MULTIPOLYGON (((125.22166 10.43444, 125.22195 ...
# 62  POLYGON ((121.49977 16.63361, 121.50491 16.633...
# 63  MULTIPOLYGON (((121.25219 14.30791, 121.25322 ...
# 64  MULTIPOLYGON (((121.93639 12.09722, 121.93667 ...
# 65  MULTIPOLYGON (((125.19167 11.12556, 125.19111 ...
# 66  MULTIPOLYGON (((124.39638 6.21300, 124.46550 6...
# 67  MULTIPOLYGON (((124.19624 7.19008, 124.19596 7...
# 68  POLYGON ((123.60448 9.30056, 123.60511 9.30055...
# 69  MULTIPOLYGON (((124.08972 12.54889, 124.09111 ...
# 70  POLYGON ((124.78861 6.60905, 124.79580 6.59667...
# 71  MULTIPOLYGON (((125.07361 9.89472, 125.07333 9...
# 72  POLYGON ((124.65561 6.87044, 124.66508 6.86998...
# 73  MULTIPOLYGON (((120.80135 5.45708, 120.80081 5...
# 74  MULTIPOLYGON (((125.87021 9.54064, 125.87033 9...
# 75  MULTIPOLYGON (((126.41750 7.96417, 126.41778 7...
# 76  POLYGON ((120.63007 15.73335, 120.63052 15.729...
# 77  MULTIPOLYGON (((119.46694 4.58694, 119.46639 4...
# 78  MULTIPOLYGON (((120.08285 14.75048, 120.08222 ...
# 79  MULTIPOLYGON (((122.09467 7.53152, 122.09467 7...
# 80  MULTIPOLYGON (((122.06223 6.87278, 122.06250 6...
# 81  MULTIPOLYGON (((122.84063 7.27694, 122.84048 7...
#
# [82 rows x 12 columns]

# %%
fig, ax = plt.subplots(1, figsize=(10, 15), frameon=True)

ph0 = gpd.GeoDataFrame.from_file("Datasets/provinces.shp")
ph0.plot(ax=ax, cmap='Greens', edgecolor='#555555', k=18)
ax.set_title('Regions of the Philippines')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

#for ind, row in ph0.iterrows():
#    ax.text(row["geometry"].centroid.x, row["geometry"].centroid.y,
#            row["PROVINCE"])

# %%
df_vp['region'].unique()
# Out:
# array(['REGION IV-A', 'CAR', 'ARMM', 'REGION VI', 'REGION I', 'REGION II',
#        'REGION III', 'REGION VII', 'REGION VIII', 'REGION X',
#        'REGION XIII', 'REGION V', 'REGION IX', 'REGION XII', 'NIR',
#        'REGION XI', 'NCR', 'REGION IV-B', nan, 'OAV'], dtype=object)
